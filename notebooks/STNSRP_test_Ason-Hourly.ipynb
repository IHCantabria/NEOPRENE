# %% [markdown]
# # NEOPRENE notebooks
#
# ***
#
# This notebook is part of a notebook collection available at the [NEOPRENE Project Site](https://github.com/IHCantabria/NEOPRENE) for illustration, reproducibility and reusability purposes. This notebook is licensed under the [Creative Commons Attribution 4.0 International License](http://creativecommons.org/licenses/by/4.0).
#
# ![Creative Commons License >](https://i.creativecommons.org/l/by/4.0/88x31.png)

# %% [markdown]
# # Calibrating and synthetic simulations of Rainfall with the STNSRPM.
#
#
# In this script we calibrate the STNSRPM (Spatio Temporal Neyman Scott Rectangular Pulse Model) using several rainfall series from Tenerife Island with a semi-arid climate (BSh-BSk). The calibration parameters are used to simulate several decades of synthetic rainfall data which can be very useful for rainfall extreme analysis or disaggregation purposes, among other things.
#
# The script also contains:
#
# 1. a validation section where the observed series are compared with the simulated ones in terms of their statistics and exceedance probabilities.
#
# 2. a disaggregation function to disaggreate daily to hourly rainfall data.

# %% [markdown]
# ### Load packages

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from scipy.interpolate import interp1d
import tqdm

# %%
import math as mt
from datetime import date
from datetime import timedelta
from scipy import stats

# %%
import sys
sys.path.insert(1, '../NEOPRENE/')

# %%
from NEOPRENE.STNSRP.HiperParams import Calibration as Calhps, Simulation as Simhps
from NEOPRENE.STNSRP.Statistics import Statistics
from NEOPRENE.STNSRP.utils import compare_statistics, datetime2matlabdnJavi 
from NEOPRENE.STNSRP.Calibration import Calibration
from NEOPRENE.STNSRP.MathematicalPropertiesSTNSRP import STNSRP_fi_min
from NEOPRENE.NSRP.Simulation import Simulation as Simulation_NSRP
from NEOPRENE.STNSRP.Simulation import Simulation

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import time
start_time = time.time()

# %% [markdown]
# ### Loading daily rainfall for Tenerife Island (now for Sierra Nevada)

# %% [markdown]
# __Cuidado que las series tienen que ser coetáneas en el tiempo__

# %%
path_1 = './auxiliary-materials/Ason/Hourly/'

# %%
## Loading rainfall series
Series_SN = pd.read_csv(path_1 + 'Inventario_Seriestemporales_Hour.csv', index_col=0, parse_dates=True)
Series_SN[Series_SN.values<0]=np.nan
Input_Series=Series_SN.copy()
del Series_SN

# %%
Input_Series.to_csv(path_1 + 'Inventario_Seriestemporales_Hour.csv')

# %%
## Loading attributes for the series
Attributes_SN = pd.read_csv(path_1 + 'Inventario_Atributos_Hourly.csv')
Input_Attr=pd.DataFrame()
Input_Attr['ID']=Attributes_SN.Id
Input_Attr['X']=Attributes_SN.Longitud.values
Input_Attr['Y']=Attributes_SN.Latitud.values
Input_Attr['Elevation']=Attributes_SN.Height.values

# %%
#Input_Attr = Input_Attr.iloc[0:5]

# %%
## Shorting ID series to match with Input_Attr
Input_Series = Input_Series[Input_Attr.ID]

# %% [markdown]
# ### Plotting rainfall series, seasonality and gauge position

# %%
f, (ax0, ax1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]}, figsize=(20, 5))

t1=str(Input_Series.index.year[0]); t2=str(Input_Series.index.year[-1])
Input_Series.plot(xlim=(t1, t2),  ylim=(0, 50), ax = ax0)
ax0.grid(True)
ax0.set_ylabel('mm/hour')

grouped_m = Input_Series.groupby(lambda x: x.month)
Month_sum=grouped_m.sum()*24/(len(Input_Series>=0)/30)
Month_sum.plot(ax = ax1)
ax1.grid(True)
ax1.set_ylabel('mm/month')
# Out:
# Text(0, 0.5, 'mm/month')

# %%
plt.plot(Input_Attr.X, Input_Attr.Y, '.r')
plt.grid()

# %% [markdown]
# ### Calibration
#
# Compleate...

# %%
# Reading hiperparamteres for the calibration
hiper_params_cal = Calhps('./Input_Cal_Ason-Hourly.yml')

# %%
# Input statistics calculated from several Rainfall series
statistics_model_1 = Statistics(hiper_params_cal, time_series = Input_Series, attributes = Input_Attr)

# Input statistics from file 
#statistics_model_2 = Statistics(hiper_params_cal, file = 'auxiliary-materials/statististics_Bilbao.csv')

# %%
CAL              = Calibration(hiper_params_cal) 
CAL1             = CAL(statistics_model_1, Input_Series, verbose=True)
os.makedirs('./CAL5/')
CAL1.save_files('./CAL5/')#save python objects
# Out:
# [20, 5000]
#
#
# ################################################################################
# Adjustment of parameters using the Particle Swarm Optimization (PSO)
#
#
#
# Fitting the months = (1, 2, 3)
#
# Initialization number  = 0
# Initial best position  1.3278616754221595 [1.66498199e-02 4.31282831e+01 8.80301111e+01 2.09757427e-01
#  6.80363864e-01]
# Iteration number  = 0
# Total error = 1.3278616754221595
# Iteration number  = 1
# Total error = 1.3278616754221595
# Iteration number  = 2
# Total error = 0.9205637926604147
# Iteration number  = 3
# Total error = 0.9205637926604147
# Iteration number  = 4
# Total error = 0.8922587809411626
# Iteration number  = 5
# Total error = 0.8747286123719977
# Iteration number  = 6
# Total error = 0.7850236541379023
# Iteration number  = 7
# Total error = 0.7850236541379023
# Iteration number  = 8
# Total error = 0.7700771562578818
# Iteration number  = 9
# Total error = 0.7700771562578818
# Iteration number  = 10
# Total error = 0.7547130145446115
# Iteration number  = 11
# Total error = 0.7547130145446115
# Iteration number  = 12
# Total error = 0.741087785346516
# Iteration number  = 13
# Total error = 0.741087785346516
# Iteration number  = 14
# Total error = 0.7360435730558548
# Iteration number  = 15
# Total error = 0.7353776110147066
# Iteration number  = 16
# Total error = 0.7353776110147066
# Iteration number  = 17
# Total error = 0.7351326477987952
# Iteration number  = 18
# Total error = 0.7326764189270121
# Iteration number  = 19
# Total error = 0.7326764189270121
# Iteration number  = 20
# Total error = 0.7324846997564024
# Iteration number  = 21
# Total error = 0.7249225521988396
# Iteration number  = 22
# Total error = 0.7187600663991274
# Iteration number  = 23
# Total error = 0.7085662719009183
# Iteration number  = 24
# Total error = 0.6691668248002256
# Iteration number  = 25
# Total error = 0.6614241892454237
# Iteration number  = 26
# Total error = 0.6435554898647357
# Iteration number  = 27
# Total error = 0.60946865058912
# Iteration number  = 28
# Total error = 0.60946865058912
# Iteration number  = 29
# Total error = 0.5782511229580702
# Iteration number  = 30
# Total error = 0.5782511229580702
# Iteration number  = 31
# Total error = 0.5782511229580702
# Iteration number  = 32
# Total error = 0.5727042380498059
# Iteration number  = 33
# Total error = 0.5686374957135724
# Iteration number  = 34
# Total error = 0.5677532444574483
# Iteration number  = 35
# Total error = 0.5677532444574483
# Iteration number  = 36
# Total error = 0.5677532444574483
# Iteration number  = 37
# Total error = 0.5677532444574483
# Iteration number  = 38
# Total error = 0.5675219731607768
# Iteration number  = 39
# Total error = 0.5617158479587762
# Iteration number  = 40
# Total error = 0.5617158479587762
#
# Fitting the months = (4, 5, 6)
#
# Initialization number  = 0
# Initial best position  1.7922432072350052 [6.02584833e-03 2.19612231e+01 8.94397666e+00 2.20360730e-01
#  1.53896713e-01]
# Iteration number  = 0
# Total error = 1.7922432072350052
# Iteration number  = 1
# Total error = 1.7922432072350052
# Iteration number  = 2
# Total error = 1.0447112534519027
# Iteration number  = 3
# Total error = 1.0447112534519027
# Iteration number  = 4
# Total error = 0.7679770942369238
# Iteration number  = 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6084/4236545928.py in <module>
#       1 CAL              = Calibration(hiper_params_cal)
# ----> 2 CAL1             = CAL(statistics_model_1, Input_Series, verbose=True)
#       3 os.makedirs('./CAL5/')
#       4 CAL1.save_files('./CAL5/')#save python objects
#
# e:\github\neoprene\NEOPRENE\STNSRP\Calibration.py in __call__(self, statistics, time_series, verbose)
#     162                     if verbose:
#     163                         print('Iteration number  = ' + str(Steps))
# --> 164                     mySwarm.step()
#     165                     Steps += 1
#     166                     (b, bp) = mySwarm.getBest()
#
# e:\github\neoprene\NEOPRENE\STNSRP\PSOMdJ.py in step(self)
#      95
#      96     def step(self):
# ---> 97         [i.update(self._best_position) for i in self._workers]
#      98         self._bestList = [i._best for i in self._workers]
#      99         tentative = np.min(self._bestList)
#
# e:\github\neoprene\NEOPRENE\STNSRP\PSOMdJ.py in <listcomp>(.0)
#      95
#      96     def step(self):
# ---> 97         [i.update(self._best_position) for i in self._workers]
#      98         self._bestList = [i._best for i in self._workers]
#      99         tentative = np.min(self._bestList)
#
# e:\github\neoprene\NEOPRENE\STNSRP\PSOMdJ.py in update(self, swarmBest)
#      32         #print np.sqrt(np.sum(self._velocity**2))
#      33         #print self._position, swarmBest
# ---> 34         self.fvalue = self._parent._Function(self._position)
#      35         self.testValue()
#      36
#
# e:\github\neoprene\NEOPRENE\STNSRP\libs_STNSRP.py in __call__(self, ind)
#     343                         h=int(self.s[ii].split("_")[1])
#     344                         d=dist_aux[jj]
# --> 345                         a=NSRP_cross_correlation(h,l, landa, mu_c, eta, xi, betha, alpha, alpha_p, fi_may, d)\
#     346                         /NSRP_covariance(h,l, landa, mu_c, eta, xi, betha, alpha, alpha_p)
#     347                         e_aux =w1*((1-(a/cross_corr_aux[jj]))**2 + (1-(cross_corr_aux[jj]/a))**2)
#
# e:\github\neoprene\NEOPRENE\STNSRP\MathematicalPropertiesSTNSRP.py in NSRP_cross_correlation(h, l, landa, mu_c, eta, xi, betha, alpha, alpha_p, fi_may, d)
#     243
#     244         result.append(NSRP_covariance(h,l, landa, mu_c, eta, xi, betha, alpha, alpha_p)\
# --> 245         -2*landa[i]*(1-P_fi_d(fi_may[i], d))*mu_c[i]*E_X(1/xi[i], alpha[i], 2)*A/(eta[i]**3))
#     246
#     247     return multiply(result)
#
# e:\github\neoprene\NEOPRENE\STNSRP\MathematicalPropertiesSTNSRP.py in P_fi_d(fi_may, d)
#     282     Ecuación 9: A space-time Neyman-Scott model of rainfall: Empirical analysis of extremes"""
#     283
# --> 284     result=(1/30)*sum_fy(fi_may, d) -(1/30)*fy(fi_may, d, 0.0)
#     285     return result
#     286
#
# e:\github\neoprene\NEOPRENE\STNSRP\MathematicalPropertiesSTNSRP.py in sum_fy(fi_may, d)
#     273 def sum_fy(fi_may, d):
#     274     sum=0
# --> 275     for ii, i in enumerate(np.arange(1,5)):
#     276         aux=2*fy(fi_may, d, 2*np.pi*i/20) + 4*fy(fi_may, d, (((2*np.pi*i)+np.pi)/20))
#     277         sum=sum+aux
#
# KeyboardInterrupt:

# %%
# Reading hiperparamteres for the simulation
hiper_params_sim = Simhps('./Input_Sim_Ason-Hourly.yml')

# %%
SIM              = Simulation(hiper_params_sim) 
# Input parameters from the model

# SIM1             = SIM(params_cal = CAL1, Input_Series = Input_Series, Input_Attr = Input_Attr)

SIM1             = SIM(params_cal =['./CAL5/Calibrated_parameters.csv',
                                    './CAL5/xi_months.csv'], 
                       Input_Series = Input_Series, Input_Attr = Input_Attr)

# %%
os.makedirs('./SIM5/')
SIM1.save_files('./SIM5/')

# %%
print("--- %s seconds ---" % (time.time() - start_time))
